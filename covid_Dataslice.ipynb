# %% [markdown]
# <a href="https://colab.research.google.com/github/Charliebond125/CORD-19_data_slice/blob/main/covid_Dataslice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import os, re, time

# %%
""" depending on preferred method of uploading data
can use either direct upload to session, or mounting google drive """

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
covid_data = pd.read_csv('/content/drive/MyDrive/Data for colab/metadata.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (1,4,5,6,13,14,15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# converting first 1000 documents into a csv file that we can use
""" at this stage, 90k documents will be too large to use. cutting the amount of required docs to 1000
makes the dataset easier to handle """
covid_data = covid_data.loc[:1000].to_csv('covid_data.csv')

# %%
df = pd.read_csv('covid_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cord_uid                                       sha source_x  \
# 0           0  ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb      PMC
# 1           1  02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d      PMC
# 2           2  ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927      PMC
# 3           3  2b73a28n  348055649b6b8cf2b9a376498df9bf41f7123605      PMC
# 4           4  9785vg6d  5f48792a5fa08bed9f56016f4981ae2ca6031b32      PMC
#
#                                                title                    doi  \
# 0  Clinical features of culture-proven Mycoplasma...  10.1186/1471-2334-1-6
# 1  Nitric oxide: a pro-inflammatory mediator in l...           10.1186/rr14
# 2    Surfactant protein-D and pulmonary host defense           10.1186/rr19
# 3               Role of endothelin-1 in lung disease           10.1186/rr44
# 4  Gene expression in epithelial cells in respons...           10.1186/rr61
#
#       pmcid  pubmed_id license  \
# ...
